# %%
# Install Dependencies
# %pip install anthropic python-dotenv
# Out:
# ...
#   Using cached docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
# Using cached docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# ...
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# ...
#
#   Attempting uninstall: typing-extensions
#
#     Found existing installation: typing_extensions 4.12.2
#
#     Uninstalling typing_extensions-4.12.2:
#
#    ---------------------------------------- 0/4 [typing-extensions]
#    ---------------------------------------- 0/4 [typing-extensions]
#    ---------------------------------------- 0/4 [typing-extensions]
#    ---------------------------------------- 0/4 [typing-extensions]
#    ---------------------------------------- 0/4 [typing-extensions]
#    ---------------------------------------- 0/4 [typing-extensions]
#    ---------------------------------------- 0/4 [typing-extensions]
#    ---------------------------------------- 0/4 [typing-extensions]
# ...

# %%
# Load env Variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API Client

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
# First helper funtion. This function will aid us in maintaining the history
from email.mime import message


def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

# Second helper function. This function will that is going to specialize in adding in assistant messages to a history
def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

# Third helper function. This function will be responsible for making the chat completion request to the API and returning the response   

def chat(messages):
    message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=messages,
)
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)


print(answer)
print(final_answer)
# Out:
# Quantum computing is a revolutionary computing paradigm that harnesses quantum mechanical phenomena like superposition and entanglement to process information in ways that can potentially solve certain complex problems exponentially faster than classical computers.
# Quantum computers use quantum bits (qubits) that can exist in multiple states simultaneously, unlike classical bits that are either 0 or 1, enabling them to perform many calculations in parallel.

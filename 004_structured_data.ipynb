# %%
# Load env variables and create client

from dotenv import load_dotenv

load_dotenv()



from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
# Helper functions

from email.mime import message


def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0, stop_sequences=None):

    params = {
        "model":model,
        "max_tokens":1000,
        "messages":messages,
        "temperature":temperature,
    }

    if system:
        params["system"] = system

    if stop_sequences:
        params["stop_sequences"] = stop_sequences

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Exercise!

# Use message prefilling and stop sequences only to get three different commands in a single response
# there should not be any commments or explanation
# Hint: message prefilling isn't limitated to just charracters like ``


messages = []

prompt = """
Generate three different samples AWS CLI commands. Each should be very short.
"""

add_user_message(messages, prompt)
add_assistant_message(messages, "Here are all three single block without any comments:\n```bash")

text = chat(messages, stop_sequences=["```"])
text.strip()
# Out:
# 'aws s3 ls s3://my-bucket\n\naws ec2 describe-instances --instance-ids i-1234567890abcdef0\n\naws iam list-users --max-items 10'

# %%
from IPython.display import Markdown

Markdown(text)
# Out:
# aws s3 ls s3://my-bucket
#
# aws ec2 describe-instances --instance-ids i-1234567890abcdef0
#
# aws iam list-users --max-items 10
